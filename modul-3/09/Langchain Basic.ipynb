# %% [markdown]
# # Langchain Basic Operations and Functions

# %% [markdown]
# ## Install Dependencies
# Make sure you have the required packages installed

# %%
# !pip install -qU langchain langchain-openai openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 19.2 MB/s eta 0:00:00

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.3

# %% [markdown]
# ## Input API Key Credential

# %%
# connect google colab to your drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# setup your credentials in "Secrets" menu in Colab
import os
from google.colab import userdata

OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %% [markdown]
# ## Import Required Libraries

# %%
from IPython.display import display, Markdown
from google.colab import userdata
from langchain_openai import ChatOpenAI

# %% [markdown]
# ## Langchain Invoke

# %%
# setting model parameters
model = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=OPENAI_API_KEY,
)

# %%
# perform simple text generation with invoke
response = model.invoke("Jelaskan apa yang dimaksud LLM?")
response
# Out:
# AIMessage(content='LLM adalah singkatan dari "Large Language Model," yang merujuk pada jenis model kecerdasan buatan yang dirancang untuk memahami dan menghasilkan bahasa alami. Model ini dibangun menggunakan teknik pembelajaran mendalam (deep learning) dan dilatih pada sejumlah besar data teks dari berbagai sumber, seperti buku, artikel, dan situs web.\n\nBerikut adalah beberapa poin penting mengenai LLM:\n\n1. **Ukuran dan Kapasitas:** LLM memiliki jutaan atau bahkan miliaran parameter, yang memungkinkannya untuk menangkap pola, makna, dan struktur dalam bahasa dengan cara yang sangat kompleks.\n\n2. **Kemampuan Generatif:** LLM dapat menghasilkan teks yang koheren dan relevan berdasarkan input yang diberikan. Ini memungkinkan model untuk digunakan dalam berbagai aplikasi, seperti pembuatan konten, percakapan manusia-mesin, dan bahkan penulisan kode.\n\n3. **Pemahaman Konteks:** LLM dapat memahami konteks dan nuansa bahasa, sehingga dapat menjawab pertanyaan, merespons pernyataan, dan terlibat dalam diskusi yang lebih alami.\n\n4. **Fine-Tuning:** Meskipun LLM dilatih secara umum, mereka juga bisa disesuaikan lebih lanjut (fine-tuning) untuk tugas spesifik atau bidang tertentu, sehingga meningkatkan akurasi dan relevansi hasilnya untuk aplikasi tertentu.\n\n5. **Contoh Populer:** Beberapa contoh LLM yang terkenal termasuk GPT-3 dan GPT-4 dari OpenAI, BERT dari Google, dan model-model lainnya yang dikembangkan oleh berbagai perusahaan dan institusi penelitian.\n\nLLM memiliki banyak potensi untuk digunakan dalam berbagai bidang, tetapi juga membawa tantangan, seperti masalah bias dalam data pelatihan dan etika penggunaan.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 355, 'prompt_tokens': 16, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CwQxlrRmUNBhRxZOIaWtn8GMFMj5x', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba78e-af73-7b10-9c13-6e7a4cdffb80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 355, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# access answer output from LLM
answer = response.content

# %%
# show answer in markdown style
display(Markdown(answer))
# Out:
# LLM adalah singkatan dari "Large Language Model," yang merujuk pada jenis model kecerdasan buatan yang dirancang untuk memahami dan menghasilkan bahasa alami. Model ini dibangun menggunakan teknik pembelajaran mendalam (deep learning) dan dilatih pada sejumlah besar data teks dari berbagai sumber, seperti buku, artikel, dan situs web.
#
# Berikut adalah beberapa poin penting mengenai LLM:
#
# 1. **Ukuran dan Kapasitas:** LLM memiliki jutaan atau bahkan miliaran parameter, yang memungkinkannya untuk menangkap pola, makna, dan struktur dalam bahasa dengan cara yang sangat kompleks.
#
# 2. **Kemampuan Generatif:** LLM dapat menghasilkan teks yang koheren dan relevan berdasarkan input yang diberikan. Ini memungkinkan model untuk digunakan dalam berbagai aplikasi, seperti pembuatan konten, percakapan manusia-mesin, dan bahkan penulisan kode.
#
# 3. **Pemahaman Konteks:** LLM dapat memahami konteks dan nuansa bahasa, sehingga dapat menjawab pertanyaan, merespons pernyataan, dan terlibat dalam diskusi yang lebih alami.
#
# 4. **Fine-Tuning:** Meskipun LLM dilatih secara umum, mereka juga bisa disesuaikan lebih lanjut (fine-tuning) untuk tugas spesifik atau bidang tertentu, sehingga meningkatkan akurasi dan relevansi hasilnya untuk aplikasi tertentu.
#
# 5. **Contoh Populer:** Beberapa contoh LLM yang terkenal termasuk GPT-3 dan GPT-4 dari OpenAI, BERT dari Google, dan model-model lainnya yang dikembangkan oleh berbagai perusahaan dan institusi penelitian.
#
# LLM memiliki banyak potensi untuk digunakan dalam berbagai bidang, tetapi juga membawa tantangan, seperti masalah bias dalam data pelatihan dan etika penggunaan.

# %%
# access token usages
token_usage = response.usage_metadata
token_usage
# Out:
# {'input_tokens': 16,
#  'output_tokens': 355,
#  'total_tokens': 371,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# calculate price for one hit question
# assume that 1 usd = 17_000 idr

input_tokens = token_usage['input_tokens']
output_tokens = token_usage['output_tokens']
price_usd = (0.15*input_tokens + 0.6*output_tokens)/1_000_000
price_idr = price_usd*17_000
print(f"Price :Rp {price_idr}")
# Out:
# Price :Rp 3.6618

# %% [markdown]
# ## Langchain Message

# %%
from langchain.messages import HumanMessage, AIMessage, SystemMessage

# write AI characteristics and persona in system message
system_msg = SystemMessage("Kamu adalah asisten yang ramah dan ceria. Jawab pertanyaan User dengan sopan dan gunakann emoji apabila diperlukan.")

# write your question in human message
human_msg = HumanMessage("Halo, apa kabar?")

# Use with chat models
messages = [system_msg, human_msg]
response = model.invoke(messages)  # Returns AIMessage

# %%
answer = response.content
display(Markdown(answer))
# Out:
# Halo! Saya baik-baik saja, terima kasih! 😊 Bagaimana dengan kabar kamu? Semoga baik juga!

# %% [markdown]
# # Reasoning

# %%
from langchain_openai import ChatOpenAI

reasoning = {
    "effort": "medium",  # 'low', 'medium', or 'high'
    "summary": "auto",  # 'detailed', 'auto', or None
}

llm = ChatOpenAI(model="gpt-5-nano", reasoning=reasoning, api_key=OPENAI_API_KEY)

# %%
response = llm.invoke("Why do parrots have colorful feathers?")
reasoning_steps = [b for b in response.content_blocks if b["type"] == "reasoning"]
print(" ".join(step["reasoning"] for step in reasoning_steps))
# Out:
# **Explaining parrot coloration**
#
# I need to answer the user's question about why parrots have colorful feathers. It’s likely tied to evolutionary biology, particularly sexual selection, where bright colors attract mates and signal health. These colors also aid in species recognition and social signaling, helping birds identify each other. Moreover, in their tropical habitats, vivid plumage can blend in with flowers and fruits, even if they may stand out sometimes. Overall, their coloration serves multiple important functions! **Exploring parrot colors**
#
# Parrots display vibrant colors like red, blue, green, and yellow, which serve different purposes. Green helps them blend in with foliage, while red and blue stand out in specific lighting. Their diet affects these colors since they rely on carotenoids, which can signal their health and foraging skills. Some feathers reflect UV light, making them more attractive to potential mates. Additionally, structural coloration results from light scattering. Factors like breeding selection, predation behavior, and seasonal changes also play a role in their coloration. It's a complex topic! **Considering parrot coloration**
#
# From a human perspective, bright colors make parrots appealing as pets, although they are wild creatures in their natural habitats. Parrots have colorful feathers primarily for mate attraction and species recognition. Their colors are also influenced by diet and reflect UV light, enhancing their signaling to potential mates. Green feathers help with camouflage in foliage, while some colors indicate health. Although bright plumage might be a disadvantage in certain environments, the benefits typically outweigh the costs in the canopy. It's fascinating to see these dynamics! **Outlining parrot coloration**
#
# I’ll present the factors influencing parrot coloration. First, there's the evolutionary purpose, where stronger coloration relates to sexual selection and mate choice. Different color patterns serve for species recognition and social interactions, helping avoid interbreeding. Additionally, their colors often come from diet-derived pigments like carotenoids. UV vision plays a role, as their plumage can appear more vibrant. In captivity, colors can change due to genetics and diet, leading to variations like lutino or albino. I can offer a concise bullet list or detailed examples based on the user's preference. **Explaining parrot colors**
#
# Parrots are so colorful mainly because evolution favored bright feathers for several reasons.
#
# - They attract mates and indicate health; bright plumage signals good genes and successful foraging.
# - Distinct color patterns help with species recognition and social interactions, reducing accidental hybridization.
# - Many colors arise from carotenoids in their diet, indicating access to nutritious food.
# - Blue and green colors often come from structural feathers and can appear vibrant in UV light.
# - In their habitat, some colors provide camouflage, especially in dappled light.
# - Seasonal variation can affect brightness, and sometimes both sexes are colorful.
#
# In short, their coloration results from a mix of mate choice, diet, and social signaling. If the user wants to know more about a specific parrot species or the science behind it, I'm ready to help!

# %% [markdown]
# ## Input Document in Prompt

# %%
import base64
file_path = "/content/drive/MyDrive/Purwadhika/Update Materi Langchain/8 - Langchain Basics/QA_sample.pdf"

# %%
with open(file_path, "rb") as f:
    file_data = f.read()
file_base64 = base64.b64encode(file_data).decode("utf-8")

# %%
import base64
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "file",
                    "file": {
                        "filename": file_path,
                        "file_data": f"data:application/pdf;base64,{file_base64}",
                    }
                },
                {
                    "type": "text",
                    "text": "What is the topic of document?",
                }
            ],
        },
    ],
)

print(completion.choices[0].message.content)
# Out:
# The document appears to focus on an AI Engineering Bootcamp, specifically details about the 2025 o2line AI Engineering Class, including information about mentors, students, class format, and curriculum creators.

# %%
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI


multimodal_llm = ChatOpenAI(model="gpt-4o-mini")

filename = "QA_sample.pdf"

content_block = {
    "type": "file",
    "base64": file_base64,
    "mime_type": "application/pdf",
    "filename": filename,
}

msg = {
    "role": "user",
    "content": [
        {
            "type": "text",
            # Update prompt as desired
            "text": "What is the topic of document?",
        },
        content_block,
    ],
}

result = multimodal_llm.invoke([msg])
print(result.content)
# Out:
# The document appears to focus on the 2025 o2line AI Engineering Class. It includes information about the mentor, students, reasons for online class sessions despite the designation "o2line," and details about the curriculum creators. Key points include:
#
# - **Mentors**: Dandy Arif Rahman for one group and Rusnandi Fikri for another.
# - **Students**: Clara, Natasha, and Caroline.
# - **Online Class Reason**: Demonstrations were held in the first week of September.
# - **Curriculum Creators**: Rusnandi Fikri, Dandy Arif Rahman, and two others.
#
# Overall, the document seems to outline the structure and individuals involved in this AI Engineering program.

# %%
img_url = "https://munley.com/wp-content/uploads/People-Crossing-on-Pedestrian-Lane-e1729276338922.png"

msg = {
    "role": "user",
    "content": [
        {"type": "text", "text": "Describe the content of this image."},
        {"type": "image", "url": img_url},
    ]
}
result = multimodal_llm.invoke([msg])
print(result.content)
# Out:
# The image shows a busy urban crosswalk with multiple pedestrians walking in various directions. The crosswalk consists of wide white stripes on a gray road surface. In the background, yellow taxis and motorcycles are visible waiting at an intersection. There are also cyclists and people on the sidewalks, creating a lively urban scene. The overall atmosphere conveys the hustle and bustle typical of a city environment.

# %% [markdown]
# ## Structured Output

# %% [markdown]
# ### Pydantic Model

# %%
from pydantic import BaseModel, Field
from langchain.agents import create_agent


class ContactInfo(BaseModel):
    """Contact information for a person."""
    name: str = Field(description="The name of the person")
    email: str = Field(description="The email address of the person")
    phone: str = Field(description="The phone number of the person")

agent = create_agent(
    model="gpt-4o-mini",
    response_format=ContactInfo  # Auto-selects ProviderStrategy
)

result = agent.invoke({
    "messages": [{"role": "user", "content": "Extract contact info from: John Doe, john@example.com, (555) 123-4567"}]
})

print(result["structured_response"])
# ContactInfo(name='John Doe', email='john@example.com', phone='(555) 123-4567')
# Out:
# name='John Doe' email='john@example.com' phone='(555) 123-4567'

# %% [markdown]
# ### Dataclass

# %%
from dataclasses import dataclass
from langchain.agents import create_agent


@dataclass
class ContactInfo:
    """Contact information for a person."""
    name: str # The name of the person
    email: str # The email address of the person
    phone: str # The phone number of the person

agent = create_agent(
    model="gpt-4o-mini",
    response_format=ContactInfo  # Auto-selects ProviderStrategy
)

result = agent.invoke({
    "messages": [{"role": "user", "content": "Extract contact info from: John Doe, john@example.com, (555) 123-4567"}]
})

result["structured_response"]
# ContactInfo(name='John Doe', email='john@example.com', phone='(555) 123-4567')
# Out:
# ContactInfo(name='John Doe', email='john@example.com', phone='(555) 123-4567')

# %% [markdown]
# ### TypeDict

# %%
from typing_extensions import TypedDict
from langchain.agents import create_agent


class ContactInfo(TypedDict):
    """Contact information for a person."""
    name: str # The name of the person
    email: str # The email address of the person
    phone: str # The phone number of the person

agent = create_agent(
    model="gpt-4o-mini",
    response_format=ContactInfo  # Auto-selects ProviderStrategy
)

result = agent.invoke({
    "messages": [{"role": "user", "content": "Extract contact info from: John Doe, john@example.com, (555) 123-4567"}]
})

result["structured_response"]
# {'name': 'John Doe', 'email': 'john@example.com', 'phone': '(555) 123-4567'}
# Out:
# {'name': 'John Doe', 'email': 'john@example.com', 'phone': '(555) 123-4567'}

# %% [markdown]
# # ChatPromptTemplate

# %% [markdown]
# ## ChatPromptTemplate for input any variables

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate(
    [
        ("system", "You are a helpful AI bot. Your name is {name}."),
        ("human", "Hello, how are you doing?"),
        ("ai", "I'm doing well, thanks!"),
        ("human", "{user_input}"),
    ]
)

prompt_value = template.invoke(
    {
        "name": "Bob",
        "user_input": "What is your name?",
    }
)

# %%
prompt_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful AI bot. Your name is Bob.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, how are you doing?', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm doing well, thanks!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is your name?', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## ChatPromptTemplate for input conversation

# %%
# In addition to Human/AI/Tool/Function messages,
# you can initialize the template with a MessagesPlaceholder
# either using the class directly or with the shorthand tuple syntax:

template = ChatPromptTemplate(
    [
        ("system", "You are a helpful AI bot."),
        # Means the template will receive an optional list of messages under
        # the "conversation" key
        ("placeholder", "{conversation}"),
        # Equivalently:
        # MessagesPlaceholder(variable_name="conversation", optional=True)
    ]
)

prompt_value = template.invoke(
    {
        "conversation": [
            ("human", "Hi!"),
            ("ai", "How can I assist you today?"),
            ("human", "Can you make me an ice cream sundae?"),
            ("ai", "No."),
        ]
    }
)

# %%
prompt_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful AI bot.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}), AIMessage(content='How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Can you make me an ice cream sundae?', additional_kwargs={}, response_metadata={}), AIMessage(content='No.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])])

# %% [markdown]
# ## ChatPromptTemplate for user input

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate(
    [
        ("system", "You are a helpful AI bot. Your name is Carl."),
        ("human", "{user_input}"),
    ]
)

prompt_value = template.invoke("Hello, there!")
# Equivalent to
# prompt_value = template.invoke({"user_input": "Hello, there!"})

# %%
prompt_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful AI bot. Your name is Carl.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, there!', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# # PromptTemplate

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate.from_template(
   "Summarize the following text in {summary_length} sentences: {text}"
)
dynamic_prompt = template.format(
   summary_length=3, text="LangChain is a framework that integrates LLMs."
)
print(dynamic_prompt)
# Out:
# Summarize the following text in 3 sentences: LangChain is a framework that integrates LLMs.

# %% [markdown]
# # FewShotPromptTemplate

# %%
from langchain_core.prompts import FewShotPromptTemplate
examples = [
 {"input" : "I was charged twice for my subscription this month", "output" : "Billing Issue"},
 {"input" : "The app crashes frequently", "output" : "Technical Problem"},
 {"input" : "can you explain how to upgrade my plan?", "output" : "General Inquiry"},
]

example_template = """
Ticket: {input}
Category: {output}
"""

few_shot_prompt = FewShotPromptTemplate(
   examples=examples,
   example_prompt=PromptTemplate(input_variables=["input", "output"], template=example_template),
   prefix="Classify the following customer support tickets into one of the categories:'Billing Issue', 'Technical problem', or 'General Inquiry'.\n\n",
   suffix="\nTicket: {user_input}\nCategory:",
   input_variables=["user_input"])

print(few_shot_prompt.format(user_input="I was charged twice for my subscription this month"))
# Out:
# Classify the following customer support tickets into one of the categories:'Billing Issue', 'Technical problem', or 'General Inquiry'.
#
#
#
#
# Ticket: I was charged twice for my subscription this month
# Category: Billing Issue
#
#
#
# Ticket: The app crashes frequently
# Category: Technical Problem
#
#
#
# Ticket: can you explain how to upgrade my plan?
# Category: General Inquiry
#
#
#
# Ticket: I was charged twice for my subscription this month
# Category:
