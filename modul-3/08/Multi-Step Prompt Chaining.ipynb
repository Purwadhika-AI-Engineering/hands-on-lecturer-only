# %% [markdown]
# # Multi-Step Prompt Chaining
#
# In this notebook, we'll explore how to do **prompt chaining** to handle complex tasks using OpenAI models.
# We'll cover three patterns:
# - Sequential chaining
# - Conditional chaining
# - Looping chaining

# %% [markdown]
# ## Setup
# Install OpenAI Python SDK and set your API key.

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.93.3)
# Collecting openai
#   Downloading openai-1.95.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Downloading openai-1.95.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.93.3
#     Uninstalling openai-1.93.3:
#       Successfully uninstalled openai-1.93.3
# Successfully installed openai-1.95.1

# %%
import openai
from openai import OpenAI
from google.colab import userdata
import os

# Make sure you set your OPENAI_API_KEY as environment variable:
# (In Colab: click on the left, go to "Variables", and add OPENAI_API_KEY)
# Retrieve the API key and store it to variable
openai.api_key = userdata.get("OPENAI_API_KEY")
client = OpenAI(api_key=openai.api_key)

# %% [markdown]
# First, we create a helper function called `get_completion` that sends a prompt to the OpenAI chat model and returns the text response. This helps keep our prompt chaining code clean, simple, and reusable.

# %%
def get_completion(prompt, model="gpt-4o"):
    """
    A helper function to get completion from OpenAI chat models.
    """
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Part 1: Sequential Chaining

# %% [markdown]
# In **sequential chaining**, we break a complex task into smaller subtasks.
# Each step's output becomes the next step's input.

# %% [markdown]
# Let's analyze a paragraph about a family and do multiple steps:
#
# **Paragraph:**
# > "John is 23 years old, his sister Anna just turned 19 last month, and their father David is now 50. Their grandmother, who moved in recently, is 75 years old."
#
# We'll chain four steps:
# 1. Extract all ages into a list
# 2. Identify the oldest person mentioned
# 3. Generate a short summary sentence about the family’s age range

# %%
paragraph = """
John is 23 years old, his sister Anna just turned 19 last month, and their father David is now 50.
Their grandmother, who moved in recently, is 75 years old.
"""

# Step 1: Extract ages as list
prompt1 = f"Extract all ages mentioned in this paragraph: '''{paragraph}''' \n make the output format as name: age"
ages_list = get_completion(prompt1)
print("Step 1 - Extracted Ages:")
print(ages_list)

# Step 2: Identify oldest person
prompt2 = f"Based on this {ages_list}, who is the oldest person mentioned?"
oldest_person = get_completion(prompt2)
print("\n Step 2 - Oldest Person:")
print(oldest_person)

# Step 3: Generate summary sentence
prompt3 = f"Write a short summary sentence describing the family and who is the oldest based on this information: {oldest_person} and based on the paragraph: {paragraph}"
summary_sentence = get_completion(prompt3)
print("\nStep 3 - Summary Sentence:")
print(summary_sentence)
# Out:
# Step 1 - Extracted Ages:
# - John: 23
# - Anna: 19
# - David: 50
# - Grandmother: 75
#
#  Step 2 - Oldest Person:
# The oldest person mentioned is Grandmother, who is 75 years old.
#
# Step 3 - Summary Sentence:
# The family consists of John, his sister Anna, their father David, and their 75-year-old grandmother, who is the oldest member.

# %% [markdown]
# ## Part 2: Conditional Chaining

# %% [markdown]
# In **conditional chaining**, we decide the next prompt based on a previous result.

# %% [markdown]
# In this example, we build a **conditional prompt chain** where the *next step* depends on the *sentiment* of the text.
#
# Here’s how it works:
# - **Step 1:** Ask the model to analyze the current state of renewable energy adoption globally.
# - **Step 2:** Check the sentiment of that analysis (positive, negative, or neutral).
# - **Step 3:** Based on the sentiment, send a different follow-up prompt:
#   - Positive → ask for opportunities
#   - Negative → ask for solutions
#   - Neutral → ask for key focus areas
# - **Step 4:** Return the final recommendations tailored to the sentiment.

# %%
def analyze_sentiment(text):
    prompt = f"Analyze the sentiment of the following text and respond with only one word - 'positive', 'negative', or 'neutral': {text}"
    sentiment = get_completion(prompt)

    print("\nStep 2 - Analyze Sentiment")
    print(sentiment)

    return sentiment.strip().lower()

def conditional_prompt_chain(result):
    if result is None:
        return "Initial prompt failed."
    sentiment = analyze_sentiment(result)

    print(f"Sentiment: {sentiment}\n")
    if sentiment == 'positive':
        follow_up = "Given this positive outlook, what are three potential opportunities we can explore?"
    elif sentiment == 'negative':
        follow_up = "Considering these challenges, what are three possible solutions we can implement?"
    else:  # neutral
        follow_up = "Based on this balanced view, what are three key areas we should focus on for a comprehensive approach?"

    final_result = get_completion(f"{follow_up}\n\nContext: {result}")
    return final_result

# Example usage
initial_prompt = "Analyze the current state of renewable energy adoption globally."
result = get_completion(initial_prompt)
print("Step 1 - Analyze Current State of Renewable Energy:")
print(result)

final_result = conditional_prompt_chain(result)
print("Step 3 - Solution:")
print(final_result)
# Out:
# Step 1 - Analyze Current State of Renewable Energy:
# As of 2023, the adoption of renewable energy globally has been progressing steadily, driven by technological advancements, policy support, and increasing awareness of climate change. Here are some key points regarding the current state of renewable energy adoption:
#
# 1. **Growth in Capacity**: The global capacity for renewable energy has been expanding rapidly. Solar and wind power have been the primary drivers of this growth, with significant investments in both technologies. According to the International Renewable Energy Agency (IRENA), renewable energy capacity has been increasing by an average of 8-10% annually.
#
# 2. **Cost Competitiveness**: The cost of renewable energy technologies, particularly solar photovoltaics (PV) and onshore wind, has decreased significantly over the past decade. This has made renewables more competitive with fossil fuels, even without subsidies. The levelized cost of electricity (LCOE) for solar and wind is now often lower than that of coal and natural gas in many regions.
#
# 3. **Policy and Regulation**: Governments worldwide have been implementing policies to support renewable energy adoption. These include feed-in tariffs, tax incentives, renewable portfolio standards, and auction systems. The European Union, China, and the United States have been particularly active in promoting renewable energy through policy measures.
#
# 4. **Energy Transition Goals**: Many countries have set ambitious targets for transitioning to renewable energy. The European Union aims to achieve 40% renewable energy in its energy mix by 2030, while China has set a target of 25% by the same year. The United States has also rejoined the Paris Agreement and is working towards significant reductions in carbon emissions.
#
# 5. **Technological Advancements**: Innovations in energy storage, grid integration, and smart grid technologies are facilitating the integration of renewable energy into existing energy systems. Battery storage solutions, in particular, are becoming more viable, helping to address the intermittency issues associated with solar and wind power.
#
# 6. **Investment Trends**: Investment in renewable energy continues to grow, with both public and private sectors contributing. In 2022, global investment in renewable energy reached record levels, with significant contributions from China, the United States, and Europe. Green bonds and sustainable finance are also playing a crucial role in funding renewable projects.
#
# 7. **Challenges and Barriers**: Despite the progress, there are still challenges to overcome. These include the need for improved grid infrastructure, regulatory hurdles, and the intermittency of some renewable sources. Additionally, there is a need for more investment in research and development to drive further technological advancements.
#
# 8. **Regional Variations**: The adoption of renewable energy varies significantly by region. Europe and China are leading in terms of capacity and policy support, while some developing countries are still in the early stages of adoption. However, regions like Africa and Southeast Asia are showing potential for rapid growth due to abundant natural resources and increasing energy demand.
#
# Overall, the global adoption of renewable energy is on an upward trajectory, with strong momentum driven by economic, environmental, and social factors. Continued efforts in policy, technology, and investment will be crucial to achieving a sustainable energy future.
#
# Step 2 - Analyze Sentiment
# Positive
# Sentiment: positive
#
# Step 3 - Solution:
# Given the positive outlook for renewable energy adoption, here are three potential opportunities to explore:
#
# 1. **Development of Advanced Energy Storage Solutions**: As renewable energy sources like solar and wind are intermittent, there is a growing need for efficient energy storage solutions to ensure a stable and reliable energy supply. Investing in the development and deployment of advanced battery technologies, such as solid-state batteries or flow batteries, can provide significant opportunities. These technologies can enhance grid stability, enable energy storage at scale, and facilitate the integration of renewables into the energy mix. Companies and investors can focus on R&D and commercialization of these technologies to capture market share in the expanding energy storage sector.
#
# 2. **Expansion into Emerging Markets**: While regions like Europe, China, and the United States are leading in renewable energy adoption, there is substantial potential in emerging markets, particularly in Africa and Southeast Asia. These regions have abundant natural resources and increasing energy demand, making them ideal for renewable energy projects. Companies can explore opportunities to develop solar, wind, and hydroelectric projects in these areas, leveraging local partnerships and government incentives. Additionally, providing off-grid renewable energy solutions can address energy access challenges in remote and underserved communities.
#
# 3. **Smart Grid and Grid Modernization Initiatives**: As renewable energy capacity grows, there is a critical need for modernizing grid infrastructure to handle the variable nature of renewables and improve energy distribution efficiency. Opportunities exist in developing and implementing smart grid technologies, such as advanced metering infrastructure, demand response systems, and grid automation. These technologies can optimize energy use, reduce losses, and enhance grid resilience. Companies specializing in digital solutions and grid management can capitalize on this trend by offering innovative products and services to utilities and governments aiming to upgrade their energy infrastructure.
#
# By focusing on these areas, businesses and investors can position themselves to benefit from the ongoing transition to a renewable energy future while contributing to global sustainability goals.

# %% [markdown]
# ## Part 3: Looping Chaining

# %% [markdown]
# In **looping chaining**, we repeat prompts until a condition is met.

# %% [markdown]
# In this example, we want to **extract product features one by one** from a paragraph.
# Since we don’t know how many features there are in advance, we loop:
# - At each step, we ask the LLM:
#   > “Give me ONE new feature not already listed. If there are none left, reply with 'DONE'.”
# - We keep track of the features we’ve already extracted and include them in the prompt.
# - When the model finally says “DONE”, we stop the loop.

# %%
# Original paragraph
product_paragraph = """
This smartphone comes with a 48MP rear camera, a 12MP front camera, 128GB of storage, a long-lasting 4000mAh battery,
and supports fast charging. It also has face unlock and an in-display fingerprint sensor.
"""

# Initialize empty list to collect features
features = []

# Initial prompt template
base_prompt = """
You are extracting product features from a paragraph.
List ONE new product feature you haven't already listed.
If there really are no more new features, reply exactly with 'DONE'.

Paragraph:
'''{paragraph}'''

Features already listed so far: {listed}

Remember: there ARE features in the paragraph, so find them one by one.
Return ONLY the new feature text (not numbered, not extra words), or 'DONE'.
"""

for i in range(10):  # Safety cap: max 10 iterations
    # Create prompt with current list
    listed = "; ".join(features) if features else "None"
    prompt = base_prompt.format(paragraph=product_paragraph, listed=listed)

    # Get completion
    feature = get_completion(prompt)
    print(f"🔁 Loop Step {i+1} - Extracted: {feature}")

    if "DONE" in feature.upper():
        break
    else:
        features.append(feature.strip())

print("\n📦 Final list of features extracted:")
for idx, f in enumerate(features, 1):
    print(f"{idx}. {f}")
# Out:
# 🔁 Loop Step 1 - Extracted: 48MP rear camera
# 🔁 Loop Step 2 - Extracted: 12MP front camera
# 🔁 Loop Step 3 - Extracted: 128GB of storage
# 🔁 Loop Step 4 - Extracted: long-lasting 4000mAh battery
# 🔁 Loop Step 5 - Extracted: supports fast charging
# 🔁 Loop Step 6 - Extracted: face unlock
# 🔁 Loop Step 7 - Extracted: in-display fingerprint sensor
# 🔁 Loop Step 8 - Extracted: DONE
#
# 📦 Final list of features extracted:
# 1. 48MP rear camera
# 2. 12MP front camera
# 3. 128GB of storage
# 4. long-lasting 4000mAh battery
# 5. supports fast charging
# 6. face unlock
# 7. in-display fingerprint sensor

# %% [markdown]
# ## Summary
#
# So far in this notebook, we have:
#
# 1.  Installed the necessary library (`openai`).
# 2.  Set up the OpenAI API key.
# 3.  Created a helper function `get_completion` to easily interact with the OpenAI chat model.
# 4.  Explored **Sequential Chaining** by breaking down a task into steps and feeding the output of one step into the next.
# 5.  Explored **Conditional Chaining** by using the sentiment of text to decide the next action.
# 6.  Explored **Looping Chaining** by repeatedly asking the model for more information until a condition is met.
