# %% [markdown]
# # Word Embeddings: Why They Matter More Than BoW and TF-IDF
#
# ## Overview
#
# This README explains why word embeddings have become the preferred method for text representation in modern NLP, comparing them with traditional approaches like Bag of Words (BoW) and Term Frequency-Inverse Document Frequency (TF-IDF).
#
# ## What Are Word Embeddings?
#
# Word embeddings are dense vector representations of words in a continuous vector space, where semantically similar words are positioned close to each other. Unlike traditional sparse representations, embeddings capture semantic relationships and contextual meaning.
#
# **Key characteristics:**
# - Dense vectors (typically 100-300 dimensions)
# - Capture semantic similarity
# - Learn contextual relationships
# - Continuous vector space representation
#
# ## Traditional Methods: BoW and TF-IDF
#
# ### Bag of Words (BoW)
# - Represents text as a collection of individual words
# - Ignores word order and grammar
# - Creates sparse, high-dimensional vectors
# - Each dimension represents a unique word in the vocabulary
#
# ### TF-IDF (Term Frequency-Inverse Document Frequency)
# - Extends BoW by weighting terms based on their importance
# - TF: How frequently a term appears in a document
# - IDF: How rare or common a term is across all documents
# - Still creates sparse, high-dimensional representations
#
# ## Why Word Embeddings Are Superior
#
# ### 1. **Semantic Understanding**
#
# **Traditional methods:**
# ```
# "king" and "queen" = completely different vectors
# "car" and "automobile" = no relationship captured
# ```
#
# **Word embeddings:**
# ```
# Similar words have similar vector representations
# king - man + woman ≈ queen (famous analogy)
# "car" and "automobile" vectors are close in space
# ```
#
# ### 2. **Dimensionality and Efficiency**
#
# | Method | Typical Dimensions | Sparsity |
# |--------|-------------------|-----------|
# | BoW | 10,000 - 100,000+ | 99%+ sparse |
# | TF-IDF | 10,000 - 100,000+ | 99%+ sparse |
# | Word Embeddings | 100 - 300 | Dense (0% sparse) |
#
# **Benefits:**
# - Lower memory requirements
# - Faster computation
# - Better generalization
#
# ### 3. **Context Awareness**
#
# **BoW/TF-IDF limitations:**
# - "Apple the company" vs "apple the fruit" - same representation
# - Word order completely ignored
# - No understanding of context
#
# **Word embeddings advantages:**
# - Context-dependent representations (especially with modern transformers)
# - Capture syntactic and semantic relationships
# - Handle polysemy (multiple meanings) better
#
# ### 4. **Handling Unknown Words**
#
# **BoW/TF-IDF:**
# - Unknown words = zero vectors
# - No way to infer meaning from similar words
#
# **Word embeddings:**
# - Can infer representations for unknown words
# - Subword embeddings handle out-of-vocabulary terms
# - Transfer learning from pre-trained models
#
# ### 5. **Mathematical Properties**
#
# Word embeddings enable powerful mathematical operations:
#
# ```python
# # Vector arithmetic examples
# king - man + woman ≈ queen
# Paris - France + Italy ≈ Rome
# running - run + walk ≈ walking
# ```
#
# These relationships are impossible with sparse BoW/TF-IDF representations.
#
# ## When to Use Each Method
#
# ### Use BoW/TF-IDF when:
# - Simple document classification tasks
# - Interpretability is crucial
# - Limited computational resources
# - Working with very domain-specific vocabulary
# - Quick prototyping needed
#
# ### Use Word Embeddings when:
# - Semantic understanding is important
# - Working with synonyms and related terms
# - Building modern NLP applications
# - Need to capture word relationships
# - Working with multiple languages
# - Handling large vocabularies efficiently

# %%
import pandas as pd
import os

from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec, FastText

# %%
df = pd.read_csv("./data/gojek_review.csv")
df.head()
# Out:
#                                               review  rate
# 0  Sangat kecewa. Kecewa sekali. Udh top up. Mau ...     1
# 1  Ga niat ngasih promo sialan temen udh pake ref...     1
# 2  Kalau sistemnya rata begini apa bedanya yg raj...     1
# 3  Ongkosnya da mahal, minimal 16rb..... Sekarang...     1
# 4  Tolol anjing..!!!! Aplikasi yang katanga karya...     1

# %%
sentences = [word_tokenize(rev.lower()) for rev in df.review]

# %% [markdown]
# # Word2Vec
#
# **sg** (Skip-gram vs CBOW architecture)
#  - 0: **CBOW** - Continuous Bag of Words predicts the target word from surrounding context words. Faster training, works well with frequent words.
#  - 1: **Skip-gram** - Predicts surrounding context words from a target word. Better performance on infrequent words and larger datasets.
#
# **hs** (Training algorithm)
#  - 0: **Negative sampling** - Approximates softmax by sampling a few negative examples instead of computing probabilities for entire vocabulary. More efficient and often better quality embeddings.
#  - 1: **Hierarchical softmax** - Uses a binary tree structure to reduce computational complexity from O(V) to O(log V). Better for frequent words, less memory intensive.

# %%
model = Word2Vec(sentences=sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=100)

# %%
# Save Model

os.makedirs("model/w2v", exist_ok=True)
model.save("model/w2v/gojek_review.w2v")

# %%
# Load Model

model = Word2Vec.load("model/w2v/gojek_review.w2v")

# %%
# Continue Training

train_examples = [
    ["aplikasinya", "ok", "kok", ".", "sangat", "membantu", "untuk", "keseharian", "saya"],
    ["aplikasi", "gojek", "ini", "adalah", "aplikasi", "paling", "kacau", "yang", "pernah", "saya", "coba"]
]

# %%
model.train(corpus_iterable=train_examples, total_examples=len(train_examples), epochs=1)
# Out:
# (14, 20)

# %% [markdown]
# # Model Information

# %%
w2v = model.wv

# %%
len(w2v.index_to_key)
# Out:
# 1699

# %%
w2v.vector_size
# Out:
# 128

# %%
w2v["ojek"]
# Out:
# array([ 5.59152424e-01,  5.72474599e-02,  7.55264878e-01,  8.54285836e-01,
#        -1.22476317e-01, -6.32630169e-01,  1.22631860e+00,  7.34556541e-02,
#        -7.74474204e-01, -5.76847017e-01,  8.82578176e-03,  1.28283501e+00,
#         7.35742271e-01, -4.20110255e-01, -8.81494820e-01,  5.06322026e-01,
#        -8.96843135e-01, -4.69468459e-02, -2.09405392e-01, -2.81389385e-01,
#         9.79973376e-02,  3.51360589e-01, -6.89637899e-01, -1.19293094e+00,
#         4.76437718e-01, -7.87897885e-01, -8.31157386e-01,  8.38757873e-01,
#         2.17679799e-01,  6.54076785e-02, -9.60251540e-02, -1.85933232e-03,
#         8.25908542e-01,  2.09735823e+00,  1.06498444e+00, -1.00903654e+00,
#        -7.03925192e-02, -8.71329486e-01, -1.18157476e-01,  3.05253625e-01,
#         1.03689528e+00, -6.92543268e-01,  8.50634351e-02, -8.85104775e-01,
#         7.31062591e-01,  4.65420246e-01,  4.66482788e-01, -3.75585556e-01,
#         2.81665832e-01, -5.80932535e-02, -6.49541378e-01, -4.30246025e-01,
#        -9.96425450e-01, -4.01570588e-01,  5.42774677e-01, -1.29241556e-01,
#        -9.62725699e-01,  8.95105973e-02, -1.62515163e+00,  1.10543108e+00,
#        -3.46462578e-01,  1.36650527e+00,  1.40745372e-01,  8.72267962e-01,
#        -8.38562787e-01, -4.07939076e-01, -2.03467906e-01,  2.80369580e-01,
#         3.76283750e-02, -9.17298198e-01,  3.80040109e-01, -4.55697238e-01,
#        -1.39061284e+00,  3.42636287e-01,  9.61733401e-01, -3.50507915e-01,
#        -2.27792785e-01, -5.99229157e-01, -2.74715543e-01, -1.27601847e-01,
#        -2.28962213e-01,  1.97238043e-01,  7.30783403e-01,  2.67147779e-01,
#         1.64109552e+00,  2.78706998e-01, -1.05719864e+00, -4.37821448e-02,
#        -7.03069270e-01,  4.09816355e-01,  6.36134684e-01, -6.48865163e-01,
#        -2.94562548e-01, -8.45696628e-01, -1.81016788e-01, -6.26889169e-01,
#         1.58278018e-01, -1.38602071e-02,  1.93685398e-01, -5.06246686e-01,
#        -2.96322703e-01, -1.68947563e-01, -8.35590780e-01,  4.64283079e-01,
#         8.00289929e-01, -3.32200676e-01, -1.24020469e+00, -4.34140235e-01,
#         1.08740520e+00, -3.44468094e-02, -6.27146602e-01, -1.74599305e-01,
#        -5.75343370e-01, -4.45672095e-01, -2.87320107e-01, -5.57960458e-02,
#        -2.89391220e-01,  3.81195880e-02,  9.71022546e-02, -4.05457824e-01,
#        -8.60016167e-01, -3.36816609e-01, -4.57979649e-01, -2.41645247e-01,
#        -5.13381898e-01,  2.31956467e-01,  1.16159439e+00, -3.52283657e-01],
#       dtype=float32)

# %% [markdown]
# # Sanity Check

# %%
# Similar Words

w2v.similar_by_word("mahal", topn=5)
# Out:
# [('tarifnya', 0.5362880229949951),
#  ('murah', 0.46824347972869873),
#  ('tarif', 0.46639284491539),
#  ('asyik', 0.46133482456207275),
#  ('ongkos', 0.44796183705329895)]

# %%
# Similar Words

w2v.similar_by_word("ojek", topn=5)
# Out:
# [('online', 0.591876745223999),
#  ('luar', 0.48862308263778687),
#  ('utama', 0.4852003753185272),
#  ('transportasi', 0.4664663076400757),
#  ('tarifnya', 0.45505982637405396)]

# %%
w2v.similar_by_word("ojoooool", topn=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 w2v.similar_by_word("ojoooool", topn=5)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/intura310/lib/python3.10/site-packages/gensim/models/keyedvectors.py:862, in KeyedVectors.similar_by_word(self, word, topn, restrict_vocab)
#     860 def similar_by_word(self, word, topn=10, restrict_vocab=None):
#     861     """Compatibility alias for similar_by_key()."""
# --> 862     return self.similar_by_key(word, topn, restrict_vocab)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/intura310/lib/python3.10/site-packages/gensim/models/keyedvectors.py:888, in KeyedVectors.similar_by_key(self, key, topn, restrict_vocab)
#     864 def similar_by_key(self, key, topn=10, restrict_vocab=None):
#     865     """Find the top-N most similar keys.
#     866
#     867     Parameters
#    (...)
#     886
#     887     """
# --> 888     return self.most_similar(positive=[key], topn=topn, restrict_vocab=restrict_vocab)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/intura310/lib/python3.10/site-packages/gensim/models/keyedvectors.py:841, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     838         weight[idx] = item[1]
#     840 # compute the weighted average of all keys
# --> 841 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842 all_keys = [
#     843     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     844 ]
#     846 if indexer is not None and isinstance(topn, int):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/intura310/lib/python3.10/site-packages/gensim/models/keyedvectors.py:518, in KeyedVectors.get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516         total_weight += abs(weights[idx])
#     517     elif not ignore_missing:
# --> 518         raise KeyError(f"Key '{key}' not present in vocabulary")
#     520 if total_weight > 0:
#     521     mean = mean / total_weight
#
# KeyError: "Key 'ojoooool' not present in vocabulary"

# %% [markdown]
# # FastText vs Word2Vec - Key Differences
#
# **Subword Information**
#
# - Word2Vec: Treats each word as an atomic unit. Unknown words = no representation.
# - FastText: Breaks words into character n-grams (subwords). Can handle unknown words by combining subword vectors.
#
# **Out-of-Vocabulary (OOV) Problem**
#
# - Word2Vec: Cannot represent words not seen during training.
# - FastText: Can generate embeddings for new/misspelled words using subword components.
#
# **Morphology Awareness**
#
# - Word2Vec: "running" and "run" are completely separate entities.
# - FastText: Understands that "running" and "run" share subword patterns, creating related embeddings.
#
# **Example:**
#
# - Word not in training: "unhappiness"
# - Word2Vec: No embedding available
# - FastText: Combines subwords like "un-", "happy", "-ness" to create a meaningful representation
#
# **Trade-off:** FastText is more robust but uses more memory and can be slower due to subword processing.

# %%
model = FastText(sentences=sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=100)

# Save Model

os.makedirs("model/fasttext", exist_ok=True)
model.save("model/fasttext/gojek_review.w2v")

model = FastText.load("model/fasttext/gojek_review.w2v")

# %%
w2v = model.wv

# %%
w2v["ojooooool"]
# Out:
# array([ 1.02551408e-01,  2.16047963e-04, -1.49550512e-01,  2.46270016e-01,
#        -8.75908509e-02, -7.12696835e-02,  2.04549823e-03,  6.22986369e-02,
#         1.31184876e-01, -1.21932738e-02,  3.51572111e-02,  2.09687024e-01,
#         1.22741431e-01,  1.48962393e-01,  7.40488351e-04, -2.33099535e-02,
#        -1.60228126e-02, -2.85045132e-02,  4.61146049e-02, -2.73896139e-02,
#         4.72685546e-02, -2.02540564e-03, -1.82722788e-02, -4.43170480e-02,
#         5.22168279e-02, -2.14277714e-01,  2.27713585e-01,  2.31287535e-02,
#        -1.09238133e-01, -5.09444885e-02,  2.73674019e-02,  8.05722624e-02,
#        -2.79490471e-01, -1.88243035e-02,  1.20313294e-01, -1.37733996e-01,
#        -1.81224551e-02, -1.58432409e-01, -2.14660801e-02,  1.45038620e-01,
#         2.62174606e-02,  2.42149569e-02,  4.60908525e-02,  3.53813916e-02,
#        -1.97299998e-02,  1.39855638e-01, -2.72864457e-02, -6.80733770e-02,
#        -8.36678818e-02,  9.89049152e-02, -4.94802333e-02, -5.55551276e-02,
#        -4.96771485e-02, -2.19521001e-02, -3.95630673e-02, -1.23934187e-02,
#         2.65594184e-01, -7.49898627e-02, -4.48949188e-02, -4.17391350e-03,
#         6.91589806e-03, -9.63134021e-02, -7.06563666e-02,  1.53578818e-01,
#        -1.82470739e-01,  9.91658214e-03, -4.29534726e-03,  1.32655472e-01,
#        -8.94148126e-02,  1.20604038e-01, -8.17788467e-02, -5.12315566e-03,
#        -2.44349405e-01, -4.39113192e-02, -1.55860126e-01, -3.99980731e-02,
#        -1.57831430e-01, -1.78182766e-01,  2.40765084e-02, -3.38091403e-02,
#        -1.63012207e-01,  4.67491001e-02,  7.29599444e-04, -5.84697612e-02,
#         1.41630858e-01, -5.38316555e-02,  1.88537076e-01,  1.63125694e-01,
#        -9.47377160e-02,  8.66916217e-03, -1.16669275e-01, -5.22422120e-02,
#         6.97957501e-02, -8.73558372e-02, -1.87502950e-01,  4.80134897e-02,
#         6.13640882e-02, -9.97527987e-02, -4.96811010e-02,  9.99927372e-02,
#         2.69550073e-04,  2.06807449e-01, -2.62778830e-02, -2.13752583e-01,
#        -3.82099226e-02,  4.24874388e-02, -1.65739253e-01, -7.43914256e-03,
#         3.78500782e-02,  6.29547462e-02, -1.99654717e-02, -1.56906173e-01,
#        -6.61705388e-03,  5.54229245e-02, -8.29360727e-03,  1.49935231e-01,
#         1.46855399e-01, -5.50949238e-02, -9.25170407e-02, -2.19139725e-01,
#         6.73357025e-02, -1.18082859e-01,  3.13015729e-02, -1.52911142e-01,
#         1.47614796e-02,  6.50247186e-02,  1.17473453e-01, -1.96237087e-01],
#       dtype=float32)

# %%
w2v.similar_by_word("ojoooool", topn=5)
# Out:
# [('ojol', 0.9864288568496704),
#  ('ojek', 0.5667917132377625),
#  ('kompetitor', 0.4712102711200714),
#  ('konsumen', 0.43776801228523254),
#  ('angkot', 0.43296676874160767)]
